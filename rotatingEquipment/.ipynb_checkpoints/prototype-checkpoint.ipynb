# %% [markdown]
# # Audio data analysis to Avoid Uplanned Downtime of Rotating Equipment
# (Leonard)
#
# **Purpose**: Predicate possible machine break down
#
# The Audio data can be used to predicate possible break down. Audio analysis is about analyzing and understanding audio signals captured by digital devices, with numerous applications in the enterprise, healthcare, productivity, and smart cities.
#
# Monitoring machine condition by sound has been common in industrial settings for several decades. Seasoned maintenance experts can identify problems in the machines they monitor just by listening to them and realizing that “something doesn’t sound right.” With the advent of machine learning and big data, it is feasible to teach machines to detect anomalies, to help predict when preventative maintenance might be necessary.
#
# Other applications include:
# * customer satisfaction analysis from customer support calls
# * media content analysis and retrieval
# * medical diagnostic aids and patient monitoring
# * assistive technologies for people with hearing impairments
# * public safety

# %% [markdown]
# # Data
# (Tharindu Wijemuni)
#
#
# The company has accumulated historical vibration data, and labelled. These data can be used for classification problem.
#
# Besides audio files from machines, Machine health can be impacted by the operation status. Some machines are easier to get into problems in certain conditions. So other non-audio related features are also interesting:
# * Average/Min/Max value of temperature to date
# * Average/Min/Max value of vibration
# * amplitude per frequency to date
# * Expected RPM (typical working load)
# * Average/Min/Max value of RPM to date
# * Asset type

# %% [markdown]
# # Explore Data
#
# (Chamila WICKRAMASINGHE )
#
# Clustering audio data into groups. Different types of machines could have unique vibration patterns. The clustering will help to split different scenaros.  Then get the vibration specialists to investigate if they belong to actual distinct type of vibrations and if they have some significance in the type of maintenance needed. Different groups might have different sound patterns identfied as problems.
# The group itself is a good feature for modelling. Or if having enough data, we can build own model for each group.
#
# We can explore data, to find which features more correlation. The feature engineering will help us.
#
# We also can transform audio data into frequency domain.

# %% [markdown]
# # Prepare Data
# (Lloyd WOOD)
# * Data transformation, transform data into frequency domain
# * scaling
# * feature selections
# * split data into training, validation and test, for cross validation

# %% [markdown]
# # ML Methods to use
#
# Surpervised Learning
#
# * SVM - Tharindu Wijemuni
# * Full connected Neural Network (we can cosnider auto-encode, CNN, or 2d LSTM) - Leonard

# %% [markdown]
# # Metrics
#
# (Chamila WICKRAMASINGHE)
#
# Confusion Matrix can be used for check.
#
# ### Recall and Precision Trade off
# * More sensitive is RECALL since we don't want to miss any real issue that could lead to unplanned down-time.
#
# * It is ok to have the false-positive rate a bit high since planned down time is not as costly. It is better to check likely issues than trying to be very accurate and risking an unplanned down time.
#
# * Design model to produce probability. So we can ask experts to double inspect if probability is around 0.5.

# %% [markdown]
# # Possible obstacles
# (Enamul Haq PATHAN)
# * Unknown data quality, audio data could include noises
# * Different Parts
# * Imbalanced data set - abnormality could occurance in rare percentage
# * How to best combine audio data and non-audio data
# * Will new working enviroment or new model of machines make trained model invalid?

# %% [markdown]
# # Prototyping

# %% [markdown]
# ## 1, Data Set
# * Industrial Machine Data Set
#
# MIMII Dataset: Sound Dataset for Malfunctioning Industrial Machine Investigation and Inspection. (https://zenodo.org/record/3384388#.YJhseE7itPY)
#
# This dataset is a sound dataset for malfunctioning industrial machine investigation and inspection (MIMII dataset). It contains the sounds generated from four types of industrial machines, i.e. valves, pumps, fans, and slide rails. Each type of machine includes seven individual product models*1, and the data for each model contains normal sounds (from 5000 seconds to 10000 seconds) and anomalous sounds (about 1000 seconds).
#
# * Prototyping Data Set
#     - Due to laptop limited processing power, rather than using the industrial open data set, this prototype uses 2 simple audit files to explain the idea
#         - applause.wav, a noisy sound - simulate abnormal machine
#         - lync_ringing.wav, a nice ring tone - simulate normal machine

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import librosa
import sys

# %%
import IPython.display as ipd
import librosa.display

# %%
audio_data = './APPLAUSE.WAV'
x , sr = librosa.load(audio_data, sr=None) #disable resampling
print(type(x), type(sr))
print(x.shape, sr) #This returns an audio time series as a numpy array with a default sampling rate(sr) of 8KHZ, single channel
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (28015,) 8000

# %%
audio2_data = './LYNC_ringing.wav'
x2 , sr2 = librosa.load(audio2_data, sr=8000) 
print(type(x2), type(sr2))
print(x2.shape, sr2) #This returns an audio time series as a numpy array with a default sampling rate(sr) of 8KHZ, single channel
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (30000,) 8000

# %%
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(audio2_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
plt.plot(x);
plt.title('Signal');
plt.xlabel('Time (samples)');
plt.ylabel('Amplitude');

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x2, sr=sr2)

# %% [markdown]
# ### 2, Fourier transform
#
# * The Fourier transform is a mathematical formula that allows us to decompose a signal into it’s individual frequencies and the frequency’s amplitude.
# * The result is called a spectrum.Spectrogram as a bunch of FFTs stacked on top of each other.
# ![Fourier transform](ft.jpg "Fourier transform")

# %%
n_fft = 2048
ft = np.abs(librosa.stft(x[:n_fft], hop_length = n_fft+1))

plt.figure(figsize=(14, 5))
plt.plot(ft);
plt.title('Spectrum');
plt.xlabel('Frequency Bin');
plt.ylabel('Amplitude');
plt.show()

# %%
n_fft = 2048
ft = np.abs(librosa.stft(x2[:n_fft], hop_length = n_fft+1))

plt.figure(figsize=(14, 5))
plt.plot(ft);
plt.title('Spectrum');
plt.xlabel('Frequency Bin');
plt.ylabel('Amplitude');
plt.show()

# %%
X = librosa.stft(x, n_fft=1024, hop_length=512) #short-time Fourier transform
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar(format='%+2.0f dB') 
#The vertical axis shows frequencies (from 0 to 4kHz), and the horizontal axis shows the time of the clip.

# %%
X = librosa.stft(x, n_fft=1024, hop_length=512) #short-time Fourier transform
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

# %%
X2 = librosa.stft(x2, n_fft=1024, hop_length=512) #short-time Fourier transform
Xdb2 = librosa.amplitude_to_db(abs(X2))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb2, sr=sr2, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

# %% [markdown]
# ### 3, Extract feature
#  * mel-scaled power (energy-squared) spectrogram
#  A mel spectrogram is a spectrogram where the frequencies are converted to the mel scale.
#
#  * mel scale
#  In 1937, Stevens, Volkmann, and Newmann proposed a unit of pitch such that equal distances in pitch sounded equally distant to the listener. This is called the mel scale.

# %%
mel_spect = librosa.feature.melspectrogram(y=x, sr=sr, n_fft=1024, hop_length=512, power=2.0)
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
plt.figure(figsize=(14, 5))
librosa.display.specshow(mel_spect, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram');
plt.colorbar(format='%+2.0f dB');

# %%
mel_spect2 = librosa.feature.melspectrogram(y=x2, sr=sr2, n_fft=1024, hop_length=512, power=2.0)
mel_spect2 = librosa.power_to_db(mel_spect2, ref=np.max)
plt.figure(figsize=(14, 5))
librosa.display.specshow(mel_spect2, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram');
plt.colorbar(format='%+2.0f dB');

# %%
mel_spect = librosa.feature.melspectrogram(y=x, sr=sr, n_fft=1024, hop_length=512, power=2.0)
log_mel_spectrogram = 20.0 / 2.0 * np.log(mel_spect + sys.float_info.epsilon)
log_mel_spectrogram.shape
# Out:
# (128, 55)

# %% [markdown]
# ### 4, Define Neural Network
# This is simple full connected network.

# %%
import keras
from keras.models import Model
from keras.layers import Input, Dense, Flatten
# Out:
# Using TensorFlow backend.

# %%
model = keras.Sequential([
    Flatten(input_shape=(128, 55)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_1 (Flatten)          (None, 7040)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               901248
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# ...
# Total params: 909,569
# Trainable params: 909,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.adam(learning_rate=0.01), metrics=['accuracy'])

# %%
#model.fit(X, y, epochs=150, batch_size=10)

# %% [markdown]
# ### 5, Evaluate Model

# %%
import sklearn.metrics as metrics

# %%
#test_loss, test_acc = model.evaluate(test_X,  test_y, verbose=2)
#score = metrics.roc_auc_score(test_y, model.predict(test_X))
#metrics.confusion_matrix(test_y, model.predict(test_X))
