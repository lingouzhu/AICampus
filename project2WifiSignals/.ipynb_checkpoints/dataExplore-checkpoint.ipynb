# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Read Dataset

# %%
dswifi = pd.read_csv("../../wifi_data.csv",sep=',')

# %%
dswifi.head()
# Out:
#    WifiAccessPoint_0  WifiAccessPoint_1  WifiAccessPoint_2  WifiAccessPoint_3  \
# 0               -125              -65.0              -67.0              -71.0
# 1               -121                NaN              -76.0                NaN
# 2               -130                NaN              -98.0                NaN
# 3               -125              -49.0              -56.0              -63.0
# 4               -117                NaN              -75.0              -82.0
#
#    WifiAccessPoint_4  WifiAccessPoint_5  WifiAccessPoint_6  WifiAccessPoint_7  \
# 0                NaN              -71.0              -74.0              -48.0
# 1              -79.0              -81.0              -72.0              -66.0
# 2                NaN                NaN                NaN              -75.0
# 3              -63.0              -47.0              -69.0              -70.0
# 4                NaN                NaN                NaN                NaN
#
#    WifiAccessPoint_8  WifiAccessPoint_9  ...  WifiAccessPoint_84  \
# 0              -91.0              -39.0  ...                 NaN
# 1              -74.0              -56.0  ...               -89.0
# 2                NaN              -74.0  ...                 NaN
# 3              -73.0              -68.0  ...                 NaN
# 4                NaN              -82.0  ...                 NaN
#
#    WifiAccessPoint_85  WifiAccessPoint_86  WifiAccessPoint_87  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    WifiAccessPoint_88  WifiAccessPoint_89  WifiAccessPoint_90         x  \
# 0                 NaN                 NaN                 NaN  0.220686
# 1                 NaN                 NaN                 NaN  0.356841
# 2                 NaN                 NaN                 NaN  0.271492
# 3                 NaN                 NaN                 NaN  0.413128
# 4                 NaN                 NaN                 NaN  0.324798
#
#           y    location_coded
# 0  0.692311  location_3626775
# 1  0.707761  location_3627737
# 2  0.395226  location_3626772
# 3  0.860029  location_3628699
# 4  0.107172  location_3627731
#
# [5 rows x 94 columns]

# %% [markdown]
# ### Check Data
# * WIFI strength is in negative. I beleive **WIFI strength sounds in dbm** means small negative is higher than larger negative (Refer to https://www.metageek.com/training/resources/wifi-signal-strength-basics.html)
# * Some strength are NULL. I believe **NULL means no signal** plans to assign a very negative value. But for plotting, just fill 0
# * 23 records misses X/Y
# * I beleive PCF will make model more efficient, need test
# * location_coded looks a very good encoding for the position. we shall use this for classification modelling.
# * it sounds a idea to create a lookup between X/Y and location_coded, so once classifed, can be reversed back to X/Y
# * not very sure how to structure it as regression problem. But maybe we can pipeline two models, the first model is for X, and second model is for Y, and the output of the first model will be sent to 2nd model, as additional feature. This strucutre need more study.
# * A good paper discuss indoor positioning http://noiselab.ucsd.edu/ECE228_2019/Reports/Report27.pdf

# %%
dswifi.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3853 entries, 0 to 3852
# Data columns (total 94 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WifiAccessPoint_0   3853 non-null   int64
#  1   WifiAccessPoint_1   2885 non-null   float64
#  2   WifiAccessPoint_2   3421 non-null   float64
#  3   WifiAccessPoint_3   2293 non-null   float64
#  4   WifiAccessPoint_4   1929 non-null   float64
#  5   WifiAccessPoint_5   2230 non-null   float64
#  6   WifiAccessPoint_6   2190 non-null   float64
#  7   WifiAccessPoint_7   2608 non-null   float64
#  8   WifiAccessPoint_8   2242 non-null   float64
#  9   WifiAccessPoint_9   3393 non-null   float64
#  10  WifiAccessPoint_10  1578 non-null   float64
#  11  WifiAccessPoint_11  2444 non-null   float64
#  12  WifiAccessPoint_12  1653 non-null   float64
#  13  WifiAccessPoint_13  3323 non-null   float64
#  14  WifiAccessPoint_14  3341 non-null   float64
#  15  WifiAccessPoint_15  2579 non-null   float64
#  16  WifiAccessPoint_16  3531 non-null   float64
#  17  WifiAccessPoint_17  234 non-null    float64
#  18  WifiAccessPoint_18  2662 non-null   float64
#  19  WifiAccessPoint_19  1619 non-null   float64
#  20  WifiAccessPoint_20  1272 non-null   float64
#  21  WifiAccessPoint_21  1721 non-null   float64
#  22  WifiAccessPoint_22  1403 non-null   float64
#  23  WifiAccessPoint_23  1590 non-null   float64
#  24  WifiAccessPoint_24  1693 non-null   float64
#  25  WifiAccessPoint_25  1672 non-null   float64
#  26  WifiAccessPoint_26  344 non-null    float64
#  27  WifiAccessPoint_27  2412 non-null   float64
#  28  WifiAccessPoint_28  338 non-null    float64
#  29  WifiAccessPoint_29  1646 non-null   float64
#  30  WifiAccessPoint_30  2966 non-null   float64
#  31  WifiAccessPoint_31  2415 non-null   float64
#  32  WifiAccessPoint_32  2501 non-null   float64
#  33  WifiAccessPoint_33  40 non-null     float64
#  34  WifiAccessPoint_34  108 non-null    float64
#  35  WifiAccessPoint_35  392 non-null    float64
#  36  WifiAccessPoint_36  1656 non-null   float64
#  37  WifiAccessPoint_37  1059 non-null   float64
#  38  WifiAccessPoint_38  1279 non-null   float64
#  39  WifiAccessPoint_39  955 non-null    float64
#  40  WifiAccessPoint_40  327 non-null    float64
#  41  WifiAccessPoint_41  50 non-null     float64
#  42  WifiAccessPoint_42  47 non-null     float64
#  43  WifiAccessPoint_43  295 non-null    float64
#  44  WifiAccessPoint_44  1288 non-null   float64
#  45  WifiAccessPoint_45  91 non-null     float64
#  46  WifiAccessPoint_46  432 non-null    float64
#  47  WifiAccessPoint_47  56 non-null     float64
#  48  WifiAccessPoint_48  12 non-null     float64
#  49  WifiAccessPoint_49  183 non-null    float64
#  50  WifiAccessPoint_50  104 non-null    float64
#  51  WifiAccessPoint_51  314 non-null    float64
#  52  WifiAccessPoint_52  359 non-null    float64
#  53  WifiAccessPoint_53  474 non-null    float64
#  54  WifiAccessPoint_54  351 non-null    float64
#  55  WifiAccessPoint_55  32 non-null     float64
#  56  WifiAccessPoint_56  7 non-null      float64
#  57  WifiAccessPoint_57  34 non-null     float64
#  58  WifiAccessPoint_58  58 non-null     float64
#  59  WifiAccessPoint_59  264 non-null    float64
#  60  WifiAccessPoint_60  290 non-null    float64
#  61  WifiAccessPoint_61  213 non-null    float64
#  62  WifiAccessPoint_62  8 non-null      float64
#  63  WifiAccessPoint_63  105 non-null    float64
#  64  WifiAccessPoint_64  124 non-null    float64
#  65  WifiAccessPoint_65  59 non-null     float64
#  66  WifiAccessPoint_66  23 non-null     float64
#  67  WifiAccessPoint_67  48 non-null     float64
#  68  WifiAccessPoint_68  2 non-null      float64
#  69  WifiAccessPoint_69  28 non-null     float64
#  70  WifiAccessPoint_70  64 non-null     float64
#  71  WifiAccessPoint_71  65 non-null     float64
#  72  WifiAccessPoint_72  81 non-null     float64
#  73  WifiAccessPoint_73  46 non-null     float64
#  74  WifiAccessPoint_74  7 non-null      float64
#  75  WifiAccessPoint_75  33 non-null     float64
#  76  WifiAccessPoint_76  3 non-null      float64
#  77  WifiAccessPoint_77  7 non-null      float64
#  78  WifiAccessPoint_78  5 non-null      float64
#  79  WifiAccessPoint_79  18 non-null     float64
#  80  WifiAccessPoint_80  38 non-null     float64
#  81  WifiAccessPoint_81  7 non-null      float64
#  82  WifiAccessPoint_82  7 non-null      float64
#  83  WifiAccessPoint_83  40 non-null     float64
#  84  WifiAccessPoint_84  24 non-null     float64
#  85  WifiAccessPoint_85  16 non-null     float64
#  86  WifiAccessPoint_86  12 non-null     float64
#  87  WifiAccessPoint_87  4 non-null      float64
#  88  WifiAccessPoint_88  4 non-null      float64
#  89  WifiAccessPoint_89  12 non-null     float64
#  90  WifiAccessPoint_90  8 non-null      float64
#  91  x                   3830 non-null   float64
#  92  y                   3830 non-null   float64
#  93  location_coded      3853 non-null   object
# dtypes: float64(92), int64(1), object(1)
# memory usage: 2.8+ MB

# %%
dswifi.location_coded.nunique()
# Out:
# 93

# %%
dswifi.describe()
# Out:
#        WifiAccessPoint_0  WifiAccessPoint_1  WifiAccessPoint_2  \
# count        3853.000000        2885.000000        3421.000000
# mean         -126.509992         -70.085269         -69.830751
# std             5.060149          12.032363          12.010631
# min          -145.000000        -105.000000        -104.000000
# 25%          -130.000000         -79.000000         -79.000000
# 50%          -126.000000         -70.000000         -70.000000
# 75%          -123.000000         -62.000000         -61.000000
# max          -107.000000         -29.000000         -29.000000
#
#        WifiAccessPoint_3  WifiAccessPoint_4  WifiAccessPoint_5  \
# count        2293.000000        1929.000000        2230.000000
# mean          -67.711295         -67.214101         -71.913453
# std            10.309497          10.437340          13.884195
# min           -96.000000         -92.000000        -103.000000
# 25%           -75.000000         -75.000000         -83.000000
# 50%           -68.000000         -68.000000         -74.000000
# 75%           -61.000000         -61.000000         -61.000000
# max           -34.000000         -27.000000         -30.000000
#
#        WifiAccessPoint_6  WifiAccessPoint_7  WifiAccessPoint_8  \
# count        2190.000000        2608.000000        2242.000000
# mean          -75.331507         -68.036043         -75.550847
# std             9.257825           9.879260           9.212177
# min          -106.000000         -97.000000        -103.000000
# 25%           -82.000000         -75.000000         -82.000000
# 50%           -76.000000         -69.000000         -76.000000
# 75%           -69.000000         -62.000000         -69.000000
# max           -46.000000         -36.000000         -40.000000
#
#        WifiAccessPoint_9  ...  WifiAccessPoint_83  WifiAccessPoint_84  \
# count        3393.000000  ...           40.000000           24.000000
# mean          -70.144415  ...          -89.425000          -89.083333
# std            11.612418  ...            5.047911            6.177918
# min          -105.000000  ...         -101.000000          -99.000000
# 25%           -78.000000  ...          -93.000000          -92.250000
# 50%           -71.000000  ...          -90.000000          -90.000000
# 75%           -62.000000  ...          -86.000000          -87.750000
# max           -33.000000  ...          -79.000000          -71.000000
#
#        WifiAccessPoint_85  WifiAccessPoint_86  WifiAccessPoint_87  \
# count           16.000000           12.000000             4.00000
# mean           -85.937500          -87.000000           -80.75000
# std              5.065817            4.572646             7.36546
# min            -93.000000          -93.000000           -88.00000
# 25%            -89.250000          -89.250000           -86.50000
# 50%            -86.000000          -88.000000           -81.00000
# 75%            -83.500000          -84.500000           -75.25000
# max            -76.000000          -78.000000           -73.00000
#
#        WifiAccessPoint_88  WifiAccessPoint_89  WifiAccessPoint_90  \
# count            4.000000           12.000000            8.000000
# mean           -89.500000          -84.500000          -90.875000
# std              5.196152            6.171783            2.997022
# min            -95.000000          -95.000000          -95.000000
# 25%            -92.750000          -86.500000          -92.750000
# 50%            -90.000000          -85.500000          -90.500000
# 75%            -86.750000          -81.000000          -88.750000
# max            -83.000000          -75.000000          -87.000000
#
#                  x            y
# count  3830.000000  3830.000000
# mean      0.532630     0.504617
# std       0.236462     0.279598
# min       0.025027     0.023188
# 25%       0.354860     0.279469
# 50%       0.564801     0.501801
# 75%       0.692138     0.753799
# max       0.935176     0.988379
#
# [8 rows x 93 columns]

# %%
dswifi.iloc[:,:-3].min().min()
# Out:
# -145.0

# %% [markdown]
# ### Clean data
# * For plotting, remove missing X/Y
# * Fill -500 as no signal

# %%
dswifiplot = dswifi[~dswifi.x.isnull() & ~dswifi.y.isnull()].copy()

# %%
#dswifiplot.fillna(-500, inplace=True)
dswifiplot.fillna(0, inplace=True)

# %%
dswifiplot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3830 entries, 0 to 3852
# Data columns (total 94 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   WifiAccessPoint_0   3830 non-null   int64
#  1   WifiAccessPoint_1   3830 non-null   float64
#  2   WifiAccessPoint_2   3830 non-null   float64
#  3   WifiAccessPoint_3   3830 non-null   float64
#  4   WifiAccessPoint_4   3830 non-null   float64
#  5   WifiAccessPoint_5   3830 non-null   float64
#  6   WifiAccessPoint_6   3830 non-null   float64
#  7   WifiAccessPoint_7   3830 non-null   float64
#  8   WifiAccessPoint_8   3830 non-null   float64
#  9   WifiAccessPoint_9   3830 non-null   float64
#  10  WifiAccessPoint_10  3830 non-null   float64
#  11  WifiAccessPoint_11  3830 non-null   float64
#  12  WifiAccessPoint_12  3830 non-null   float64
#  13  WifiAccessPoint_13  3830 non-null   float64
#  14  WifiAccessPoint_14  3830 non-null   float64
#  15  WifiAccessPoint_15  3830 non-null   float64
#  16  WifiAccessPoint_16  3830 non-null   float64
#  17  WifiAccessPoint_17  3830 non-null   float64
#  18  WifiAccessPoint_18  3830 non-null   float64
#  19  WifiAccessPoint_19  3830 non-null   float64
#  20  WifiAccessPoint_20  3830 non-null   float64
#  21  WifiAccessPoint_21  3830 non-null   float64
#  22  WifiAccessPoint_22  3830 non-null   float64
#  23  WifiAccessPoint_23  3830 non-null   float64
#  24  WifiAccessPoint_24  3830 non-null   float64
#  25  WifiAccessPoint_25  3830 non-null   float64
#  26  WifiAccessPoint_26  3830 non-null   float64
#  27  WifiAccessPoint_27  3830 non-null   float64
#  28  WifiAccessPoint_28  3830 non-null   float64
#  29  WifiAccessPoint_29  3830 non-null   float64
#  30  WifiAccessPoint_30  3830 non-null   float64
#  31  WifiAccessPoint_31  3830 non-null   float64
#  32  WifiAccessPoint_32  3830 non-null   float64
#  33  WifiAccessPoint_33  3830 non-null   float64
#  34  WifiAccessPoint_34  3830 non-null   float64
#  35  WifiAccessPoint_35  3830 non-null   float64
#  36  WifiAccessPoint_36  3830 non-null   float64
#  37  WifiAccessPoint_37  3830 non-null   float64
#  38  WifiAccessPoint_38  3830 non-null   float64
#  39  WifiAccessPoint_39  3830 non-null   float64
#  40  WifiAccessPoint_40  3830 non-null   float64
#  41  WifiAccessPoint_41  3830 non-null   float64
#  42  WifiAccessPoint_42  3830 non-null   float64
#  43  WifiAccessPoint_43  3830 non-null   float64
#  44  WifiAccessPoint_44  3830 non-null   float64
#  45  WifiAccessPoint_45  3830 non-null   float64
#  46  WifiAccessPoint_46  3830 non-null   float64
#  47  WifiAccessPoint_47  3830 non-null   float64
#  48  WifiAccessPoint_48  3830 non-null   float64
#  49  WifiAccessPoint_49  3830 non-null   float64
#  50  WifiAccessPoint_50  3830 non-null   float64
#  51  WifiAccessPoint_51  3830 non-null   float64
#  52  WifiAccessPoint_52  3830 non-null   float64
#  53  WifiAccessPoint_53  3830 non-null   float64
#  54  WifiAccessPoint_54  3830 non-null   float64
#  55  WifiAccessPoint_55  3830 non-null   float64
#  56  WifiAccessPoint_56  3830 non-null   float64
#  57  WifiAccessPoint_57  3830 non-null   float64
#  58  WifiAccessPoint_58  3830 non-null   float64
#  59  WifiAccessPoint_59  3830 non-null   float64
#  60  WifiAccessPoint_60  3830 non-null   float64
#  61  WifiAccessPoint_61  3830 non-null   float64
#  62  WifiAccessPoint_62  3830 non-null   float64
#  63  WifiAccessPoint_63  3830 non-null   float64
#  64  WifiAccessPoint_64  3830 non-null   float64
#  65  WifiAccessPoint_65  3830 non-null   float64
#  66  WifiAccessPoint_66  3830 non-null   float64
#  67  WifiAccessPoint_67  3830 non-null   float64
#  68  WifiAccessPoint_68  3830 non-null   float64
#  69  WifiAccessPoint_69  3830 non-null   float64
#  70  WifiAccessPoint_70  3830 non-null   float64
#  71  WifiAccessPoint_71  3830 non-null   float64
#  72  WifiAccessPoint_72  3830 non-null   float64
#  73  WifiAccessPoint_73  3830 non-null   float64
#  74  WifiAccessPoint_74  3830 non-null   float64
#  75  WifiAccessPoint_75  3830 non-null   float64
#  76  WifiAccessPoint_76  3830 non-null   float64
#  77  WifiAccessPoint_77  3830 non-null   float64
#  78  WifiAccessPoint_78  3830 non-null   float64
#  79  WifiAccessPoint_79  3830 non-null   float64
#  80  WifiAccessPoint_80  3830 non-null   float64
#  81  WifiAccessPoint_81  3830 non-null   float64
#  82  WifiAccessPoint_82  3830 non-null   float64
#  83  WifiAccessPoint_83  3830 non-null   float64
#  84  WifiAccessPoint_84  3830 non-null   float64
#  85  WifiAccessPoint_85  3830 non-null   float64
#  86  WifiAccessPoint_86  3830 non-null   float64
#  87  WifiAccessPoint_87  3830 non-null   float64
#  88  WifiAccessPoint_88  3830 non-null   float64
#  89  WifiAccessPoint_89  3830 non-null   float64
#  90  WifiAccessPoint_90  3830 non-null   float64
#  91  x                   3830 non-null   float64
#  92  y                   3830 non-null   float64
#  93  location_coded      3830 non-null   object
# dtypes: float64(92), int64(1), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Plot data

# %%
x = dswifiplot.iloc[:,:-3].values
df = pd.DataFrame(x.sum(axis=1), columns = ['wifiStrength'])

# %%
np.mean(x),np.std(x)
# Out:
# (-17.7700427509827, 32.76055038342206)

# %%
df.head()
# Out:
#    wifiStrength
# 0       -1919.0
# 1       -2008.0
# 2       -1598.0
# 3       -1690.0
# 4       -1497.0

# %%
df['x'] = dswifiplot['x'].values*100
df['y'] = dswifiplot['y'].values*100

# %%
sns.set()
norm = plt.Normalize(df['wifiStrength'].min(), df['wifiStrength'].max())
sm = plt.cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])
fig, ax = plt.subplots(figsize=(12,8)) 
ax = sns.scatterplot(x='x', y='y', data=df, marker='D', palette='RdBu', hue='wifiStrength', ax=ax)

# Remove the legend and add a colorbar
ax.get_legend().remove()
ax.figure.colorbar(sm)

plt.show()

# %% [markdown]
# ### Explore PCA
# To do

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
x = dswifiplot.iloc[:,:-3].values
x = StandardScaler().fit_transform(x) # normalizing the features
#x = MinMaxScaler().fit_transform(x) # normalizing the features
x.shape
# Out:
# (3830, 91)

# %%
pca = PCA(n_components=10)
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.12566425 0.05740509 0.04622606 0.03272152 0.03048898 0.02742434
#  0.02334009 0.02291053 0.02172983 0.02133994]
